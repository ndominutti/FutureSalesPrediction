# %%
from google.colab import drive

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd gdrive/MyDrive/KAGGLE_COMPETITION/
# Out:
# /content/gdrive/MyDrive/KAGGLE_COMPETITION

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/gdrive/MyDrive/KAGGLE_COMPETITION/.git/

# %%
# !git remote add origin https://ndominutti:Cristobal856@github.com/ndominutti/FutureSalesPrediction.git

# !git remote -v
# Out:
# origin	https://ndominutti:Cristobal856@github.com/ndominutti/FutureSalesPrediction.git (fetch)
# origin	https://ndominutti:Cristobal856@github.com/ndominutti/FutureSalesPrediction.git (push)

# %%
# !git config --global user.email 'ndominutti@gmail.com'
# !git config --global user.name 'ndominutti'

# %%
# !git add .

# %%
# !git commit -m 'First commit'
# Out:
# [master (root-commit) 1950044] First commit
#  21 files changed, 3386805 insertions(+)
#  create mode 100644 Data/item_categories.csv
#  create mode 100644 Data/item_categories_translated.csv
#  create mode 100644 Data/items.csv
#  create mode 100644 Data/sales_train.csv
#  create mode 100644 Data/sample_submission.csv
#  create mode 100644 Data/shops.csv
#  create mode 100644 Data/shops_translated.csv
#  create mode 100644 Data/test.csv
#  create mode 100644 Models/LightGBM.ipynb
#  create mode 100644 Models/RandomForest.ipynb
#  create mode 100644 Models/Stacking.ipynb
#  create mode 100644 Models/XGBoost.ipynb
#  create mode 100644 Models/lgbm.pkl
#  create mode 100644 Models/lgbm_randomized_search.csv
#  create mode 100644 Models/xgb.pkl
#  create mode 100644 Models/xgb_randomized_search.csv
#  create mode 100644 Preprocessing/EDA.ipynb
#  create mode 100644 Preprocessing/Preprocessing.ipynb
#  create mode 100644 Preprocessing/Translate.ipynb
#  create mode 100644 Readme.md
#  create mode 100644 git.ipynb

# %%
# !git push origin master
# Out:
# Counting objects: 26, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (26/26), done.
# Writing objects: 100% (26/26), 23.64 MiB | 3.88 MiB/s, done.
# Total 26 (delta 3), reused 0 (delta 0)
# remote: Resolving deltas: 100% (3/3), done.
# remote: warning: GH001: Large files detected. You may want to try Git Large File Storage - https://git-lfs.github.com.
# remote: warning: See http://git.io/iEPt8g for more information.
# remote: warning: File Data/sales_train.csv is 90.22 MB; this is larger than GitHub's recommended maximum file size of 50.00 MB
# To https://github.com/ndominutti/FutureSalesPrediction.git
#  * [new branch]      master -> master
