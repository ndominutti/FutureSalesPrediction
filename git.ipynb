# %%
from google.colab import drive

# %%
drive.mount('/content/gdrive')

# %%
# %cd gdrive/MyDrive/KAGGLE_COMPETITION/

# %%
# !git init

# %%
# !git remote add origin https://ndominutti:Cristobal856@github.com/ndominutti/FutureSalesPrediction.git

# !git remote -v

# %%
# !git config --global user.email 'ndominutti@gmail.com'
# !git config --global user.name 'ndominutti'

# %%
# !git add .

# %%
# !git log

# %%
# !git commit -m 'First commit'

# %%
# !git reset HEAD "df_processed.pkl"
# Out:
# Unstaged changes after reset:
# M	git.ipynb

# %%
# !git rm "df_processed.pkl"
# Out:
# fatal: pathspec 'Data/df_processed.pkl' did not match any files

# %%
# !git reset
# Out:
# Unstaged changes after reset:
# M	git.ipynb
